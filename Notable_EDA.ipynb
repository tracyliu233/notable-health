# %% [markdown]
# # Utils

# %%
import pandas as pd
import numpy as np
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, precision_score, recall_score

# %%
df = pd.read_csv('AP_ICD10.tsv', sep='\t')
df.head()
# Out:
#                                           chf cmplnt  \
# 0  Followup: Osteoarthritis of hip; Hip pain, Pos...
# 1                                 Knee pain, Post Op
# 2        Followup: Osteoarthritis of knee; Knee pain
# 3                                           Hip pain
# 4                                 Knee pain, Post Op
#
#                                                  A/P icd10encounterdiagcode  \
# 0  Doing well post-op. Progressing as expected. o...                  M1612
# 1  The fracture is healing well in good alignment...                S82025A
# 2  Osteoarthritis of the Right knee.The patient e...                  M1711
# 3  Left hip Trocanteric Bursitis. trochanteric bu...                  M7062
# 4  Left Medial Meniscus Tear. Doing well post-op....                S83222A
#
#                              icd10encounterdiagdescr
# 0  M1612: Unilateral primary osteoarthritis, left...
# 1  S82025A: Nondisplaced longitudinal fracture of...
# 2  M1711: Unilateral primary osteoarthritis, righ...
# 3             M7062: Trochanteric bursitis, left hip
# 4  S83222A: Prph tear of medial meniscus, current...

# %%
df.dtypes
# Out:
# chf cmplnt                 object
# A/P                        object
# icd10encounterdiagcode     object
# icd10encounterdiagdescr    object
# dtype: object

# %% [markdown]
# # Data Processing

# %%
df = df[~df[['A/P', 'icd10encounterdiagcode']].isnull().any(axis=1)]

# %%
df['icd_cat']  = df.apply(lambda row: row['icd10encounterdiagcode'][:3], axis=1)
# Out:
# /Users/tracy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def tokenize_txt(row):
    new_row = re.sub(r'[^\w\s-]', '', row)
    new_row = new_row.lower().strip()
    return new_row

# %%
df['token_ap'] = df.apply(lambda row: tokenize_txt(row['A/P']), axis=1)

# %%
df_new = df[['token_ap', 'icd_cat']]

# %%
# One token_ap can map to multiple icd category
df_new.groupby(['token_ap']).icd_cat.nunique()
# Out:
# token_ap
# antalgic gait post boot removal no pathology noted activity as tolerated call with questions closed fracture metatarsal base interpreted and discussed xr foot results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# anteromedial osteoarthritis of the left knee osteoarthritis of knee 49-year-old female with left knee osteoarthritis bone-on-bone in the medial compartment spelled steroid injections visco supplementation bracing this will help some but she continued pain stable lateral joint space on stress x-ray discussed with margie the options of partial knee replacement versus total knee replacement her pain is localized only to the medial joint line she would like to explore options were partially replacement for her to my partner dr mullins has more experience with this order total knee arthroplasty                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# anteromedial osteoarthritis of the left knee osteoarthritis of knee interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# anteromedial osteoarthritis of the right knee the patient experienced significant improvement initially but now the symptoms are returning osteoarthritis of knee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# anteromedial osteoarthritis of the right knee the patient experienced significant improvement initially but now the symptoms are returning osteoarthritis of knee provided artritis en la rodilla instrucciones de cuidado - knee arthritis care instructions                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# better with 1st euflexxa osteoarthritis of knee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# bilateral knee oa remains improved with 2nd euflexxa  osteoarthritis of knee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# closed colles fracture left interpreted and discussed xr wrist results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# comminuted intraarticular right distal radius fx closed fracture of distal end of radius right                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# comminuted nondisplaced left patella fx the fracture is healing well in good alignment closed fracture of patella left interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# doing well post-op progressing as expected  fracture of lateral malleolus left acute disruption of ankle syndesmosis interpreted and discussed xr ankle results fracture of ankle complication of internal prosthetic device                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         3
# doing well post-op progressing as expected  pain in left knee send for physical therapy referral                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# doing well post-op progressing as expected acl feels intact no evidence of reinjury rupture of anterior cruciate ligament tear of lateral meniscus of knee left                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      2
# doing well post-op progressing as expected acute injury of anterior cruciate ligament left rupture of anterior cruciate ligament tear of lateral meniscus of knee left                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               2
# doing well post-op progressing as expected closed fracture proximal tibia bicondylar right closed fracture of tibial plateau complication associated with orthopedic device complication of internal prosthetic device                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               2
# doing well post-op progressing as expected complete tear knee anterior cruciate ligament left rupture of anterior cruciate ligament send for physical therapy referral tear of medial meniscus of knee left                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# doing well post-op progressing as expected deficiency of anterior cruciate ligament derangement of medial meniscus tear of lateral meniscus of knee osteoarthritis of knee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           3
# doing well post-op progressing as expected derangement of medial meniscus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# doing well post-op progressing as expected derangement of medial meniscus tear of medial meniscus of knee degeneration of lateral meniscus send for physical therapy referral                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        2
# doing well post-op progressing as expected dislocation of shoulder joint left                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# doing well post-op progressing as expected disorder of tendon of biceps                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# doing well post-op progressing as expected needs to work more on walking at lifecare osteoarthritis of hip                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# doing well post-op progressing as expected osteoarthritis of hip                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# doing well post-op progressing as expected osteoarthritis of knee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# doing well post-op progressing as expected osteoarthritis of knee derangement of medial meniscus tear of lateral meniscus of knee tear of medial meniscus of knee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# doing well post-op progressing as expected osteoarthritis of knee derangement of medial meniscus tear of lateral meniscus of knee tear of medial meniscus of knee knee hpi patient reports poppingclicking but reports no numbness no tingling no swelling no warmth no radiation down leg no drainage no fever and no chills he reports anterior he reports aching and improving he reports mild he reports ice ptot and nsaids he reports helped significantly 4 weeks post left knee ats partial mms lms knee  gait and station appearance normal gait ambulates with no assitive devices  knees inspection left no warmth no erythema no effusion portals healed bony palpation left no tenderness of the medial joint line no tenderness of the lateral joint line soft tissue palpation left no tenderness of the patellar tendon active range of motion left normal no pain with motion no crepitus strength left flexion 55 extension 55  skin left lower extremity normal  neurologic sensation on the left t12 normal l1 normal l2 normal l3 normal l4 normal l5 normal s1 normal s2 normal s345 normal    3
# doing well post-op progressing as expected osteoarthritis of knee interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# doing well post-op progressing as expected osteoarthritis of knee send for physical therapy referral                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# doing well post-op progressing as expected ready for syndesmosis screw removal fracture of lateral malleolus left acute disruption of ankle syndesmosis interpreted and discussed xr ankle results fracture of ankle complication of internal prosthetic device order surgical hardware removal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      3
# doing well post-op progressing as expected rupture of anterior cruciate ligament                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ..
# right rotator cuff tendonitis with some mdi component strain of rotator cuff capsule right interpreted and discussed xr shoulder results send for physical therapy referral                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# right thumb ulnar collateral ligament sprain sprain thumb metacarpophalangeal joint ulnar collateral ligament interpreted and discussed xr fingers results gave exos short thumb spica brace                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# right wrist sprain sprain of wrist right interpreted and discussed xr wrist results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# significant partial thickness rc tear right shoulder full thickness rotator cuff tear right order shoulder arthroscopy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# stable and ratable from shoulder standpoint partial thickness rotator cuff tear arthritis of acromioclavicular joint                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# strain of rotator cuff capsule interpreted and discussed xr shoulder results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# stress fx right femur stress fracture of shaft of femur interpreted and discussed xr femur results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# stress fx right femur stress fracture of shaft of femur order intramedullary nailing femur                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# tear of medial meniscus of knee right order knee arthroscopy tear of lateral meniscus of knee right osteoarthritis of knee interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# the fracture is healing well in good alignment  closed fracture of patella interpreted and discussed xr knee results send for physical therapy referral                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# the fracture is healing well in good alignment closed fracture of lateral malleolus left interpreted and discussed xr ankle results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# the fracture is healing well in good alignment closed fracture of neck of femur right interpreted and discussed xr hip unilateral results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# the fracture is healing well in good alignment closed fracture of tibial plateau right interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# ...
# the fracture is healing well in good alignment fracture of distal end of radius left interpreted and discussed xr wrist results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# the fracture is healing well in good alignment minimally displaced right radial styloid fx closed fracture radial styloid right interpreted and discussed xr wrist results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# the fracture is healing well in good alignment radial nerve palsy closed fracture of lower end of humerus left interpreted and discussed xr elbow results gave innovator x post-op elbow brace gave wrist brace lace up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# the fracture is healing well in good alignment supracondylar fracture femur left interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# the left knee prosthetic components are well positioned with no sign of loosening right knee oa symptoms recurring osteoarthritis of knee interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# the prosthetic components are well positioned with no sign of loosening anteromedial osteoarthritis of the left knee worsening osteoarthritis of knee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# the prosthetic components are well positioned with no sign of loosening osteoarthritis of hip interpreted and discussed xr hip unilateral results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# the prosthetic components are well positioned with no sign of loosening osteoarthritis of knee interpreted and discussed xr knee results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# torus fracture left distal radius the fracture is healing well in good alignment closed torus fracture of radius left interpreted and discussed xr wrist results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# traumatic anterior instability left shoulder anterior dislocation of shoulder joint left gave shoulder sling abduction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# traumatic anterior instability left shoulder doing well post-op progressing as expected anterior dislocation of shoulder joint left                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# trochanteric bursitis left interpreted and discussed xr hip unilateral results provided hip bursitis care instructions                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# trochanteric bursitis right interpreted and discussed xr pelvis results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# worse with recent injuries likely scar irritation with tendonitis  1 recurrent subluxation of shoulder - multidirectional m24419 recurrent dislocation unspecified shoulder  patient instructions injection of the right subacromial bursa performed physical therapy to be instructed in home rotator cuff and scapular strengthening program keep up with home therapy program for next 4 to 6 months be careful with overhead activity return if symptoms persist worsen or recur  return to office none recorded                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Name: icd_cat, Length: 165, dtype: int64

# %%
df_new.head()
# Out:
#                                             token_ap icd_cat
# 0  doing well post-op progressing as expected ost...     M16
# 1  the fracture is healing well in good alignment...     S82
# 2  osteoarthritis of the right kneethe patient ex...     M17
# 3  left hip trocanteric bursitis trochanteric bur...     M70
# 4  left medial meniscus tear doing well post-op p...     S83

# %% [markdown]
# # Data Modeling

# %%
df_new.icd_cat.nunique()
# Out:
# 34

# %%
len(df_new)
# Out:
# 240

# %%
# for each icd category it's an unbalanced classification
df_new.groupby('icd_cat').count()
# Out:
#          token_ap
# icd_cat
# G56             1
# M00             2
# M13             1
# M16            17
# M17            45
# M18             1
# M19             2
# M21             1
# M22             5
# M23            16
# M24             3
# M25             7
# M65             1
# M67             2
# M70             6
# M75            10
# M76             4
# M77             1
# M84             2
# M87             1
# S42             4
# S43             5
# S46             7
# S52             8
# S63             2
# S68             1
# S72             3
# S76             1
# S82            15
# S83            53
# S92             2
# S93             3
# T84             7
# Z89             1

# %%
def prepare_train_test_data(df_train, df_test, icd_cat):    
    # upsampling
    
    # tfidf score
    vectorizer = TfidfVectorizer()
    vectorizer.fit(df_train.token_ap.values)
    
    X_train = vectorizer.transform(df_train.token_ap.values)
    y_train = df_train.icd_cat.values == icd_cat
    
    X_test = vectorizer.transform(df_test.token_ap.values)
    y_test = df_test.icd_cat.values == icd_cat
    
    return X_train, y_train, X_test, y_test

# %%
# training and validation
for icd_cat in df_train.icd_cat.unique():
    # split train test
    test_idx = np.random.randint(len(df_new), size=int(len(df_new)/3))
    df_train = df_new[~df_new.index.isin(test_idx)]
    df_test = df_new[df_new.index.isin(test_idx)]
    
    if len(df_train[df_train.icd_cat==icd_cat])==0 or len(df_train[df_train.icd_cat==icd_cat])==0:
        continue
    print('Fitting classifer for ICD category {}'.format(icd_cat))
    X_train, y_train, X_test, y_test = prepare_train_test_data(df_train, df_test, icd_cat)
    
    # fit model
    clf = LogisticRegression()
    clf.fit(X_train, y_train)
    
    # train roc_auc
    y_train_score = clf.predict_proba(X_train)[:, 1]
    roc_auc_train = roc_auc_score(y_train, y_train_score)  
    print('Training roc_auc is {}'.format(roc_auc_train))
    
    # test roc_auc
    y_pred = clf.predict(X_test)
    precision = precision_score(y_test.astype(int), y_pred.astype(int))
    recall = recall_score(y_test.astype(int), y_pred.astype(int))
    
    print('Testing precision is {} and recall is {}'.format(precision, recall))
    print(8*'*')
# Out:
# Fitting classifer for ICD category M16
# Training roc_auc is 0.9991634132738427
# Testing precision is 1.0 and recall is 0.16666666666666666
# ********
# Fitting classifer for ICD category M17
# Training roc_auc is 0.9978041282389107
# Testing precision is 0.875 and recall is 0.5833333333333334
# ********
# Fitting classifer for ICD category M70
# Training roc_auc is 0.9964705882352941
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S83
# Training roc_auc is 0.9815233785822022
# Testing precision is 0.75 and recall is 0.6428571428571429
# ********
# Fitting classifer for ICD category M24
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S46
# Training roc_auc is 0.9992603550295858
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M25
# Training roc_auc is 0.9958579881656804
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S82
# Training roc_auc is 0.9804447852760736
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S93
# Training roc_auc is 0.9833333333333334
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category T84
# Training roc_auc is 0.9895209580838323
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S72
# /Users/tracy/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M00
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M19
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S63
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S52
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M23
# Training roc_auc is 0.9536749482401656
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category G56
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M22
# Training roc_auc is 0.9990253411306043
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S68
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M84
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M75
# Training roc_auc is 0.9984662576687117
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S42
# Training roc_auc is 0.9992732558139535
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S43
# Training roc_auc is 0.999001996007984
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M76
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category Z89
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M18
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M13
# Training roc_auc is 0.9970414201183433
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M65
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category M67
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
# Fitting classifer for ICD category S92
# Training roc_auc is 1.0
# Testing precision is 0.0 and recall is 0.0
# ********
